# %% [markdown]
# # Current Topics and Projects
# ## Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import MNLogit
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn import linear_model, metrics
from tabulate import tabulate
from pystout import pystout

# %%
df_com = pd.read_csv('comments_final.csv')
df_vid = pd.read_csv('videos.csv')

# %%
df_com.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134883 entries, 0 to 134882
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   commentID               134883 non-null  object
#  1   text                    134883 non-null  object
#  2   publishedAt             134883 non-null  object
#  3   authorID                134883 non-null  object
#  4   likeCount               134883 non-null  int64
#  5   totalReplyCount         134883 non-null  int64
#  6   parentID                134883 non-null  object
#  7   videoID                 134883 non-null  object
#  8   channelId               134883 non-null  object
#  9   username                134840 non-null  object
#  10  threat                  134882 non-null  float64
#  11  toxicity                134882 non-null  float64
#  12  identity_attack         134882 non-null  float64
#  13  insult                  134882 non-null  float64
#  14  severe_toxicity         134882 non-null  float64
#  15  sentiment               134883 non-null  object
#  16  prob_pos                134883 non-null  float64
#  17  prob_neg                134883 non-null  float64
#  18  prob_neu                134883 non-null  float64
#  19  clean_tokens            134883 non-null  object
#  20  clean_text              134883 non-null  object
#  21  channelName             134883 non-null  object
#  22  repliedID               134883 non-null  object
#  23  repliedName             5858 non-null    object
#  24  stable                  134883 non-null  int64
#  25  user_replies            134883 non-null  int64
#  26  cluster_values          134883 non-null  object
#  27  cluster                 134883 non-null  float64
#  28  stable_tox              134883 non-null  int64
#  29  stable_sent             134883 non-null  int64
#  30  personal_attack         134883 non-null  int64
#  31  personal_attack_name    13417 non-null   object
#  32  personal_attack_gender  13417 non-null   object
#  33  personal_attack_party   13417 non-null   object
#  34  in_cluster              134883 non-null  int64
# dtypes: float64(9), int64(8), object(18)
# memory usage: 36.0+ MB

# %% [markdown]
# ### Research Question 1:
# Do YouTube comments on German political YouTube accounts from the left, middle, and right exhibit significant differences in polarity and toxicity

# %%
df_vid.info()

# %%
print(df_com["stable"].describe())
print(df_com["stable_tox"].describe())
print(df_com["stable_sent"].describe())
print(df_com["in_cluster"].describe())

# %%
# Three independent variabels: toxicity and structural balance (df_com) and prob_neg of transcript (df_vid)
# toxicity and structural balance needs to be grouped and aggregated by video
grouped_data = df_com.groupby('videoID')[['toxicity', 'stable_tox', 'in_cluster']].mean().reset_index()
grouped_data.rename(columns={'toxicity': 'toxicity_mean', 'videoID': 'videovideoID', 
                             'stable_tox': 'stable_tox_mean', 'in_cluster': 'in_cluster_mean'}, inplace=True)

# merge the variables with df_vid
df_vid = pd.merge(df_vid, grouped_data, on='videovideoID', how='left')

# %%
df_vid.head()

# %%
# Make Dummies out of dependent variable: take DW as middle category
channelId_dummy = pd.get_dummies(df_vid["channelName"])
df_vid = pd.concat([df_vid, channelId_dummy], axis = 1)
df_vid.head()
# Out:
#          videoPublishedAt  videolikeCount
# 0    2022-10-02T07:32:00Z           12884  \
# 1    2022-07-12T15:51:27Z           17664
# 2    2022-09-02T15:28:00Z           22243
# 3    2022-12-08T16:30:01Z           28015
# 4    2022-12-04T08:26:00Z           17840
# ..                    ...             ...
# 148  2022-11-14T22:30:09Z             926
# 149  2022-09-02T11:42:54Z             184
# 150  2022-10-31T19:14:41Z             811
# 151  2022-03-02T12:46:57Z             218
# 152  2022-02-25T15:28:26Z             328
#
#                                                  title
# 0    Energie-Insider: Strom könnte 50 Prozent billi...  \
# 1    JETZT OFFIZIELL: Habeck will Millionen Haushal...
# 2    Mit dieser Lüge bringt der WDR Frauen in höchs...
# 3    Flüchtling ermordet Ece: Mütter warnten vor Be...
# 4    Hatespeech-Razzien: „Das sind totale Stasi-Vibes“
# ..                                                 ...
# 148  Reichensteuer, Koalitionsfrieden, Kryptocrash ...
# 149  2. September 2022 - Regierungspressekonferenz ...
# 150  Ökonomin Silja Graupe zur Ökonomisierung der B...
# 151     2. März 2022 - Regierungspressekonferenz | BPK
# 152  25. Februar 2022 - Regierungspressekonferenz |...
#
#                                            description  viewCount  likeCount
# 0    Das ist mal eine Analyse: „Die Energiekrise is...     121046      12884  \
# 1    Dramatische Pressekonferenz von Wirtschaftsmin...     225260      17664
# 2    Vergangene Woche veröffentlichte der WDR eine ...     246589      22243
# 3    Es ist gerade mal vier Tage her, dass ein Flüc...     404079      28015
# 4    Die Fragen der Woche mit Eva Vlaardingerbroek!...     206101      17840
# ..                                                 ...        ...        ...
# 148  Support ► http://www.paypal.me/JungNaiv\nDisku...      31692        926
# 149  Unterstützt unsere Arbeit ► http://www.paypal....       9768        184
# 150  Unterstützt uns finanziell ► http://www.paypal...      50880        811
# 151  Unterstützt unsere Arbeit ► http://www.paypal....      14375        218
# 152  Unterstützt unsere Arbeit ► http://www.paypal....      18566        328
#
#      commentCount            videochannelId videovideoID         channelName
# 0            1622  UCcoQ3WG2J_Xjwwyt-sJqh-w  RHsMs6KDgJI  Achtung, Reichelt!  \
# 1            3815  UCcoQ3WG2J_Xjwwyt-sJqh-w  QUJWYdu_EHk  Achtung, Reichelt!
# 2            4006  UCcoQ3WG2J_Xjwwyt-sJqh-w  bppRqICEGX8  Achtung, Reichelt!
# 3            6502  UCcoQ3WG2J_Xjwwyt-sJqh-w  c0G7qF44wLc  Achtung, Reichelt!
# 4            2635  UCcoQ3WG2J_Xjwwyt-sJqh-w  6P5Nlmw2xRE  Achtung, Reichelt!
# ..            ...                       ...          ...                 ...
# 148           104  UCv1WDP5EiipMQ__C4Cg6aow  Xyr0RWE0ELY         Jung & Naiv
# 149            48  UCv1WDP5EiipMQ__C4Cg6aow  IxmFkFU6loU         Jung & Naiv
# 150            68  UCv1WDP5EiipMQ__C4Cg6aow  yQ6tUIZHrHk         Jung & Naiv
# 151            63  UCv1WDP5EiipMQ__C4Cg6aow  7aZE5FXg-Q4         Jung & Naiv
# 152           197  UCv1WDP5EiipMQ__C4Cg6aow  EXLnEIWJjbg         Jung & Naiv
#
#      ... sentiment_transcript prob_pos_transcript  prob_neg_transcript
# 0    ...              neutral            0.004249             0.024490  \
# 1    ...              neutral            0.002900             0.016498
# 2    ...              neutral            0.004714             0.022497
# 3    ...              neutral            0.004097             0.030283
# 4    ...              neutral            0.006579             0.039146
# ..   ...                  ...                 ...                  ...
# 148  ...              neutral            0.004664             0.021504
# 149  ...              neutral            0.003379             0.011883
# 150  ...              neutral            0.005945             0.020863
# 151  ...              neutral            0.004438             0.027436
# 152  ...              neutral            0.004602             0.018321
#
#      prob_neu_transcript  toxicity_mean  stable_tox_mean  in_cluster_mean
# 0               0.971261       0.340678         0.188406         0.597308  \
# 1               0.980602       0.437257         0.067073         0.449426
# 2               0.972789       0.416470         0.103380         0.487365
# 3               0.965620       0.498905         0.090319         0.459765
# 4               0.954274       0.408469         0.092092         0.519251
# ..                   ...            ...              ...              ...
# 148             0.973832       0.223647         0.126437         0.252874
# 149             0.984738       0.261161         0.178571         0.785714
# 150             0.973192       0.259582         0.089286         0.357143
# 151             0.968126       0.222358         0.108108         0.216216
# 152             0.977077       0.303147         0.176471         0.490196
#
#      Achtung, Reichelt!  DW Deutsch  Jung & Naiv
# 0                  True       False        False
# 1                  True       False        False
# 2                  True       False        False
# 3                  True       False        False
# 4                  True       False        False
# ..                  ...         ...          ...
# 148               False       False         True
# 149               False       False         True
# 150               False       False         True
# 151               False       False         True
# 152               False       False         True
#
# [153 rows x 21 columns]

# %%
# prepare variabels for model
X = df_vid[["toxicity_mean", "prob_neg_transcript", "stable_tox_mean"]]
y = df_vid[['Jung & Naiv', 'DW Deutsch', 'Achtung, Reichelt!']]
print(X)
print(y)
# Out:
#      toxicity_mean  prob_neg_transcript  stable_tox_mean
# 0         0.340678             0.024490         0.188406
# 1         0.437257             0.016498         0.067073
# 2         0.416470             0.022497         0.103380
# 3         0.498905             0.030283         0.090319
# 4         0.408469             0.039146         0.092092
# ..             ...                  ...              ...
# 148       0.223647             0.021504         0.126437
# 149       0.261161             0.011883         0.178571
# 150       0.259582             0.020863         0.089286
# 151       0.222358             0.027436         0.108108
# 152       0.303147             0.018321         0.176471
#
# [153 rows x 3 columns]
#      Jung & Naiv  DW Deutsch  Achtung, Reichelt!
# 0          False       False                True
# 1          False       False                True
# 2          False       False                True
# 3          False       False                True
# 4          False       False                True
# ..           ...         ...                 ...
# 148         True       False               False
# 149         True       False               False
# 150         True       False               False
# 151         True       False               False
# 152         True       False               False
#
# [153 rows x 3 columns]

# %%
# check for missing values
missing_values = X.isnull().sum()
print(missing_values)

# replace NA with mean
column_means = X.mean()
X = X.fillna(column_means)
print(X)
# Out:
# toxicity_mean          0
# prob_neg_transcript    0
# stable_tox_mean        0
# dtype: int64
#      toxicity_mean  prob_neg_transcript  stable_tox_mean
# 0         0.340678             0.024490         0.188406
# 1         0.437257             0.016498         0.067073
# 2         0.416470             0.022497         0.103380
# 3         0.498905             0.030283         0.090319
# 4         0.408469             0.039146         0.092092
# ..             ...                  ...              ...
# 148       0.223647             0.021504         0.126437
# 149       0.261161             0.011883         0.178571
# 150       0.259582             0.020863         0.089286
# 151       0.222358             0.027436         0.108108
# 152       0.303147             0.018321         0.176471
#
# [153 rows x 3 columns]

# %%
# Split in test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
# Fit regression
def fit_regression(X,y):
    ''' 
    function to fit regresssion for three dummy variables as dependent variable of logistic regression
    '''

    # Split in test and train data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

    log_model = LogisticRegression()
    log_model.fit(X_train, y_train)

    # make prediction
    y_pred = log_model.predict(X_test)

    # get accuracy
    accuracy = accuracy_score(y_test, y_pred)

    # report
    classification_rep = metrics.classification_report(y_test, y_pred, output_dict=True)

    # Statsmodel provides p-value for hypothesis test
    # Add constant term to the predictor matrix (intercept)
    X_train_const = sm.add_constant(X_train)

    # Fit logistic regression model using statsmodels
    model_sm = sm.MNLogit(y_train, X_train_const)
    result = model_sm.fit()

    # calculate Odds
    odds = result.params
    
    return y_pred, accuracy, classification_rep, result, odds

# %%
channel_names = ['Jung & Naiv', 'DW Deutsch', 'Achtung, Reichelt!']
for channel in channel_names:
    # call function
    y_pred, accuracy, classification_rep, result, odds_table = fit_regression(X,y[channel])

    # print accuracy and classification report
    print("Accuracy:", accuracy)
    classification_rep_df = pd.DataFrame(classification_rep).transpose()
    print(classification_rep_df.to_latex(index=False, float_format="{:.1f}".format))

    # print result table in latex format
    # Print summary statistics
    print(result.summary().as_latex())

    print("Odds:", odds_table.to_latex(float_format="{:.3f}".format))
# Out:
# C:\Users\Raphaela\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Raphaela\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Raphaela\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Raphaela\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Raphaela\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Raphaela\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Raphaela\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Raphaela\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Raphaela\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Optimization terminated successfully.
#          Current function value: 0.316530
#          Iterations 7
# Accuracy: 0.6956521739130435
# \begin{tabular}{rrrr}
# \toprule
# precision & recall & f1-score & support \\
# \midrule
# 0.7 & 1.0 & 0.8 & 32.0 \\
# 0.0 & 0.0 & 0.0 & 14.0 \\
# 0.7 & 0.7 & 0.7 & 0.7 \\
# 0.3 & 0.5 & 0.4 & 46.0 \\
# 0.5 & 0.7 & 0.6 & 46.0 \\
# \bottomrule
# \end{tabular}
#
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}        &   Jung \& Naiv   & \textbf{  No. Observations:  } &      107    \\
# \textbf{Model:}                &     MNLogit      & \textbf{  Df Residuals:      } &      103    \\
# \textbf{Method:}               &       MLE        & \textbf{  Df Model:          } &        3    \\
# \textbf{Date:}                 & Sat, 26 Aug 2023 & \textbf{  Pseudo R-squ.:     } &   0.5091    \\
# \textbf{Time:}                 &     21:54:15     & \textbf{  Log-Likelihood:    } &   -33.869   \\
# \textbf{converged:}            &       True       & \textbf{  LL-Null:           } &   -68.994   \\
# \textbf{Covariance Type:}      &    nonrobust     & \textbf{  LLR p-value:       } & 3.772e-15   \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{ccccccc}
#    \textbf{Jung \& Naiv=1}     & \textbf{coef} & \textbf{std err} & \textbf{z} & \textbf{P$> |$z$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
# \textbf{const}                 &       8.2467  &        2.081     &     3.963  &         0.000        &        4.168    &       12.325     \\
# \textbf{toxicity\_mean}        &     -30.3276  &        5.884     &    -5.154  &         0.000        &      -41.860    &      -18.795     \\
# \textbf{prob\_neg\_transcript} &      -1.1139  &        1.686     &    -0.661  &         0.509        &       -4.418    &        2.190     \\
# \textbf{stable\_tox\_mean}     &      13.7374  &        6.061     &     2.266  &         0.023        &        1.858    &       25.617     \\
# \bottomrule
# \end{tabular}
# %\caption{MNLogit Regression Results}
# \end{center}
# Odds: \begin{tabular}{lr}
# \toprule
#  & 0 \\
# \midrule
# const & 8.247 \\
# toxicity_mean & -30.328 \\
# prob_neg_transcript & -1.114 \\
# stable_tox_mean & 13.737 \\
# \bottomrule
# \end{tabular}
#
# Optimization terminated successfully.
#          Current function value: 0.565294
#          Iterations 6
# Accuracy: 0.5869565217391305
# \begin{tabular}{rrrr}
# \toprule
# precision & recall & f1-score & support \\
# \midrule
# 0.6 & 1.0 & 0.7 & 27.0 \\
# 0.0 & 0.0 & 0.0 & 19.0 \\
# 0.6 & 0.6 & 0.6 & 0.6 \\
# 0.3 & 0.5 & 0.4 & 46.0 \\
# 0.3 & 0.6 & 0.4 & 46.0 \\
# \bottomrule
# \end{tabular}
#
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}        &    DW Deutsch    & \textbf{  No. Observations:  } &      107    \\
# \textbf{Model:}                &     MNLogit      & \textbf{  Df Residuals:      } &      103    \\
# \textbf{Method:}               &       MLE        & \textbf{  Df Model:          } &        3    \\
# \textbf{Date:}                 & Sat, 26 Aug 2023 & \textbf{  Pseudo R-squ.:     } &  0.07340    \\
# \textbf{Time:}                 &     21:54:15     & \textbf{  Log-Likelihood:    } &   -60.486   \\
# \textbf{converged:}            &       True       & \textbf{  LL-Null:           } &   -65.278   \\
# \textbf{Covariance Type:}      &    nonrobust     & \textbf{  LLR p-value:       } &  0.02247    \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{ccccccc}
#     \textbf{DW Deutsch=1}      & \textbf{coef} & \textbf{std err} & \textbf{z} & \textbf{P$> |$z$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
# \textbf{const}                 &      -2.8331  &        1.473     &    -1.924  &         0.054        &       -5.720    &        0.053     \\
# \textbf{toxicity\_mean}        &       6.4599  &        3.406     &     1.897  &         0.058        &       -0.215    &       13.135     \\
# \textbf{prob\_neg\_transcript} &       1.4346  &        0.943     &     1.521  &         0.128        &       -0.414    &        3.283     \\
# \textbf{stable\_tox\_mean}     &      -4.6603  &        4.340     &    -1.074  &         0.283        &      -13.167    &        3.847     \\
# \bottomrule
# \end{tabular}
# %\caption{MNLogit Regression Results}
# \end{center}
# Odds: \begin{tabular}{lr}
# \toprule
#  & 0 \\
# \midrule
# const & -2.833 \\
# toxicity_mean & 6.460 \\
# prob_neg_transcript & 1.435 \\
# stable_tox_mean & -4.660 \\
# \bottomrule
# \end{tabular}
#
# Optimization terminated successfully.
#          Current function value: 0.499162
#          Iterations 7
# Accuracy: 0.717391304347826
# \begin{tabular}{rrrr}
# \toprule
# precision & recall & f1-score & support \\
# \midrule
# 0.7 & 1.0 & 0.8 & 33.0 \\
# 0.0 & 0.0 & 0.0 & 13.0 \\
# 0.7 & 0.7 & 0.7 & 0.7 \\
# 0.4 & 0.5 & 0.4 & 46.0 \\
# 0.5 & 0.7 & 0.6 & 46.0 \\
# \bottomrule
# \end{tabular}
#
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}        & Achtung, Reichelt! & \textbf{  No. Observations:  } &      107    \\
# \textbf{Model:}                &      MNLogit       & \textbf{  Df Residuals:      } &      103    \\
# \textbf{Method:}               &        MLE         & \textbf{  Df Model:          } &        3    \\
# \textbf{Date:}                 &  Sat, 26 Aug 2023  & \textbf{  Pseudo R-squ.:     } &   0.2327    \\
# \textbf{Time:}                 &      21:54:15      & \textbf{  Log-Likelihood:    } &   -53.410   \\
# \textbf{converged:}            &        True        & \textbf{  LL-Null:           } &   -69.611   \\
# \textbf{Covariance Type:}      &     nonrobust      & \textbf{  LLR p-value:       } & 4.307e-07   \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{ccccccc}
# \textbf{Achtung, Reichelt!=1}  & \textbf{coef} & \textbf{std err} & \textbf{z} & \textbf{P$> |$z$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
# \textbf{const}                 &      -7.7325  &        2.116     &    -3.654  &         0.000        &      -11.880    &       -3.585     \\
# \textbf{toxicity\_mean}        &      20.4280  &        4.943     &     4.133  &         0.000        &       10.740    &       30.116     \\
# \textbf{prob\_neg\_transcript} &      -0.4908  &        1.036     &    -0.474  &         0.636        &       -2.521    &        1.539     \\
# \textbf{stable\_tox\_mean}     &      -4.3891  &        4.924     &    -0.891  &         0.373        &      -14.040    &        5.262     \\
# \bottomrule
# \end{tabular}
# %\caption{MNLogit Regression Results}
# \end{center}
# Odds: \begin{tabular}{lr}
# \toprule
#  & 0 \\
# \midrule
# const & -7.733 \\
# toxicity_mean & 20.428 \\
# prob_neg_transcript & -0.491 \\
# stable_tox_mean & -4.389 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Check conditions for logistic regression

# %%
# 1. Linearity of Log-Odds
sm.graphics.plot_partregress_grid(result)

# 2. Independence of Observations: assumed

# 3. No Multicollinearity: almost no correlation between independent variables
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif_data.to_latex(index=False, float_format="{:.1f}".format))

cov_matrix = result.cov_params()
print(cov_matrix.to_latex(index=False, float_format="{:.1f}".format))

correlation_matrix = X.corr()
print(correlation_matrix.to_latex())

# 4. Large Sample Size: reasonable sample size of 149170
print(X.describe().to_latex())

# 5. No Outliers: no unusual patterns or outliers

# 6. No Perfect Separation: independent variable has low variance
# Out:
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# \begin{tabular}{lr}
# \toprule
# feature & VIF \\
# \midrule
# toxicity_mean & 4.8 \\
# prob_neg_transcript & 1.3 \\
# stable_tox_mean & 4.3 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{rrrr}
# \toprule
# \multicolumn{4}{r}{1} \\
# const & toxicity_mean & prob_neg_transcript & stable_tox_mean \\
# \midrule
# 4.5 & -9.9 & -0.1 & -4.1 \\
# -9.9 & 24.4 & -0.1 & 2.9 \\
# -0.1 & -0.1 & 1.1 & 0.1 \\
# -4.1 & 2.9 & 0.1 & 24.2 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrr}
# \toprule
#  & toxicity_mean & prob_neg_transcript & stable_tox_mean \\
# \midrule
# toxicity_mean & 1.000000 & 0.216647 & -0.128439 \\
# prob_neg_transcript & 0.216647 & 1.000000 & -0.064327 \\
# stable_tox_mean & -0.128439 & -0.064327 & 1.000000 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrr}
# \toprule
#  & toxicity_mean & prob_neg_transcript & stable_tox_mean \\
# \midrule
# count & 153.000000 & 153.000000 & 153.000000 \\
# mean & 0.359148 & 0.102240 & 0.125371 \\
# std & 0.075860 & 0.206582 & 0.058916 \\
# min & 0.132493 & 0.006049 & 0.000000 \\
# 25% & 0.297135 & 0.020132 & 0.088646 \\
# 50% & 0.378303 & 0.029650 & 0.113990 \\
# 75% & 0.416435 & 0.053154 & 0.162037 \\
# max & 0.498905 & 0.980246 & 0.365854 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Research Question 2:
# What are the underlying factors that contribute to the polarity and toxicity of YouTube comments on German political YouTube accounts from the left, middle, and right?

# %%
df_com['personal_attack'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 134883 entries, 0 to 134882
# Series name: personal_attack
# Non-Null Count   Dtype
# --------------   -----
# 134883 non-null  int64
# dtypes: int64(1)
# memory usage: 1.0 MB

# %%
# replace empty lists of personal_attack variables with NA
df_com = df_com.replace({"personal_attack_name": "[]", "personal_attack_gender": "[]", "personal_attack_party": "[]"}, np.nan)
df_com.replace("0", 0, inplace=True)
df_com.head()
# Out:
#                     commentID
# 0  UgzNbjRq-bmbAkT8AKd4AaABAg  \
# 1  UgzLliIQM1p-mszsMJJ4AaABAg
# 2  UgyQnUE08i_MhHHR-5R4AaABAg
# 3  UgzmCbLPz_GiXJicg0l4AaABAg
# 4  UgzqdmnqOOpQkXzJ0uB4AaABAg
#
#                                                 text           publishedAt
# 0  Die Kraftwerke weiterlaufen zu lassen ist nich...  2023-05-11T19:37:05Z  \
# 1  Bitte alle kompetenten Fachleute in die Politi...  2023-03-11T11:12:50Z
# 2  Ich stimme grundsätzlich zu! Die Politik könnt...  2023-02-28T12:59:18Z
# 3  Zitat Dieter Nuhr: die Grünen sind dabei Deuts...  2023-02-21T10:23:51Z
# 4  Angebot und Nachfrage. Ein wirtschaftlicher Gr...  2022-12-30T16:21:33Z
#
#                    authorID  likeCount  totalReplyCount parentID      videoID
# 0  UCffvix1CZh19OHEKNd5HlaQ          0                0        0  RHsMs6KDgJI  \
# 1  UCO7NBsrEO1VlEgpjsqlODKg          0                0        0  RHsMs6KDgJI
# 2  UCJ_FNG2X8he2dDal7Co689A          0                0        0  RHsMs6KDgJI
# 3  UCnv0JgIk9UAYsvktFdSUsiA          0                0        0  RHsMs6KDgJI
# 4  UCYs8otO1f01y2_Fif5_Y5PQ          0                0        0  RHsMs6KDgJI
#
#                   channelId            username  ...  user_replies
# 0  UCcoQ3WG2J_Xjwwyt-sJqh-w       Dana Schlegel  ...             1  \
# 1  UCcoQ3WG2J_Xjwwyt-sJqh-w               Marti  ...             3
# 2  UCcoQ3WG2J_Xjwwyt-sJqh-w       Thomas Bracht  ...            10
# 3  UCcoQ3WG2J_Xjwwyt-sJqh-w  Gixxer NRW Germany  ...             8
# 4  UCcoQ3WG2J_Xjwwyt-sJqh-w        Lisanne Benz  ...             1
#
#                                cluster_values   cluster  stable_tox
# 0                        [0.4245987745633333]  0.424599           0  \
# 1  [0.39610165102813855, 0.30893602838888884]  0.352519           0
# 2                        [0.4192263335261031]  0.419226           0
# 3   [0.4487647916384181, 0.46313270040322574]  0.455949           0
# 4                        [0.3678198210992997]  0.367820           0
#
#    stable_sent personal_attack  personal_attack_name  personal_attack_gender
# 0            0               0                   NaN                     NaN  \
# 1            0               0                   NaN                     NaN
# 2            0               0                   NaN                     NaN
# 3            0               0                   NaN                     NaN
# 4            0               0                   NaN                     NaN
#
#    personal_attack_party in_cluster
# 0                    NaN          1
# 1                    NaN          1
# 2                    NaN          1
# 3                    NaN          1
# 4                    NaN          1
#
# [5 rows x 35 columns]

# %%
print(df_com['totalReplyCount'].describe())
print("-----")
print(df_com['likeCount'].describe())

# %%
# normalize variables
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

variables_to_normalize = ['totalReplyCount', 'likeCount']

# Fit and transform the selected variables
normalized_data = scaler.fit_transform(df_com[variables_to_normalize])

# Convert the normalized data back to a DataFrame
normalized_df = pd.DataFrame(normalized_data, columns=variables_to_normalize)

print(normalized_df)
# Out:
#         totalReplyCount  likeCount
# 0              0.000000   0.000000
# 1              0.000000   0.000000
# 2              0.000000   0.000000
# 3              0.000000   0.000000
# 4              0.000000   0.000000
# ...                 ...        ...
# 134878         0.000000   0.000592
# 134879         0.007692   0.001184
# 134880         0.000000   0.000000
# 134881         0.000000   0.000000
# 134882         0.115385   0.013914
#
# [134883 rows x 2 columns]

# %%
print(normalized_df['totalReplyCount'].describe())
print("-----")
print(normalized_df['likeCount'].describe())
# Out:
# count    134883.000000
# mean          0.001978
# std           0.013525
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: totalReplyCount, dtype: float64
# -----
# count    134883.000000
# mean          0.002477
# std           0.018429
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000592
# max           1.000000
# Name: likeCount, dtype: float64

# %%
# calculate index for independent variable "extensive discussion"
extensive_discussion1 = (normalized_df['totalReplyCount'] + normalized_df['likeCount'])/2

# raw reply count as independent variable
extensive_discussion2 = normalized_df['totalReplyCount']

# %%
# define variables
X = df_com[['prob_neg',  'identity_attack', 'personal_attack']]
y = df_com["totalReplyCount"]

# %%
# check for missing values
missing_values = X.isnull().sum()
print(missing_values)

column_means = X.mean()
X = X.fillna(column_means)
print(X.describe())
# Out:
# prob_neg           0
# identity_attack    1
# personal_attack    0
# dtype: int64
#             prob_neg  identity_attack  personal_attack
# count  134883.000000     1.348830e+05    134883.000000
# mean        0.418578     3.949268e-01         0.099471
# std         0.452481     2.710023e-01         0.299295
# min         0.000004     5.141927e-08         0.000000
# 25%         0.005772     1.581286e-01         0.000000
# 50%         0.074081     3.377392e-01         0.000000
# 75%         0.964480     6.040796e-01         0.000000
# max         0.999740     1.000000e+00         1.000000

# %%
model = sm.OLS(y, X)
result_linear = model.fit()
print(result_linear.summary().as_latex())
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}    & totalReplyCount  & \textbf{  R-squared (uncentered):}      &       0.012     \\
# \textbf{Model:}            &       OLS        & \textbf{  Adj. R-squared (uncentered):} &       0.012     \\
# \textbf{Method:}           &  Least Squares   & \textbf{  F-statistic:       }          &       530.8     \\
# \textbf{Date:}             & Sun, 27 Aug 2023 & \textbf{  Prob (F-statistic):}          &       0.00      \\
# \textbf{Time:}             &     00:49:32     & \textbf{  Log-Likelihood:    }          &  -3.6164e+05    \\
# \textbf{No. Observations:} &      134883      & \textbf{  AIC:               }          &   7.233e+05     \\
# \textbf{Df Residuals:}     &      134880      & \textbf{  BIC:               }          &   7.233e+05     \\
# \textbf{Df Model:}         &           3      & \textbf{                     }          &                 \\
# \textbf{Covariance Type:}  &    nonrobust     & \textbf{                     }          &                 \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                           & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{prob\_neg}        &       0.2427  &        0.021     &    11.796  &         0.000        &        0.202    &        0.283     \\
# \textbf{identity\_attack} &       0.5301  &        0.027     &    19.709  &         0.000        &        0.477    &        0.583     \\
# \textbf{personal\_attack} &       0.1406  &        0.032     &     4.421  &         0.000        &        0.078    &        0.203     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 321935.060 & \textbf{  Durbin-Watson:     } &       1.912     \\
# \textbf{Prob(Omnibus):} &    0.000   & \textbf{  Jarque-Bera (JB):  } & 5706502086.822  \\
# \textbf{Skew:}          &   24.355   & \textbf{  Prob(JB):          } &        0.00     \\
# \textbf{Kurtosis:}      &  1009.477  & \textbf{  Cond. No.          } &        2.49     \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] R² is computed without centering (uncentered) since the model does not contain a constant. \newline
#  [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# splitting X and y into training and testing sets
X_train, X_test,\
    y_train, y_test = train_test_split(X, y,
                                       test_size=0.4,
                                       random_state=1)
 
# create linear regression object
reg = linear_model.LinearRegression()
 
# train the model using the training sets
result = reg.fit(X_train, y_train)
 
# regression coefficients
print('Coefficients: ', reg.coef_)
 
# variance score: 1 means perfect prediction
print('Variance score: {}'.format(reg.score(X_test, y_test)))
 
# plot for residual error
 
# setting plot style
plt.style.use('fivethirtyeight')
 
# plotting residual errors in training data
plt.scatter(reg.predict(X_train),
            reg.predict(X_train) - y_train,
            color="green", s=10,
            label='Train data')
 
# plotting residual errors in test data
plt.scatter(reg.predict(X_test),
            reg.predict(X_test) - y_test,
            color="blue", s=10,
            label='Test data')
 
# plotting line for zero residual error
plt.hlines(y=0, xmin=0, xmax=0.01, linewidth=2)

plt.xlim(0, 0.01) 
plt.ylim(-1, 0.1)
 
# plotting legend
plt.legend(loc='upper right')
 
# plot title
plt.title("Residual errors")
 
# method call for showing the plot
plt.show()
# Out:
# Coefficients:  [-0.01138593 -0.37536421 -0.00711533]
# Variance score: 0.0008501854627228633

# %% [markdown]
# ### Check conditions for linear regression

# %%
# configure font 
plt.rcParams["font.family"] = "Times New Roman"

# %%
# 1. Linear relationship: not really linear
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns

# Scatter plot for the first set of data
ax1.scatter(X["identity_attack"], y, color='grey')
ax1.set_xlabel('Identity Attack')
ax1.set_ylabel('Extensive Discusssion')

# Scatter plot for the second set of data
ax2.scatter(X["prob_neg"], y, color='grey')
ax2.set_xlabel('Negative Sentiment')
ax2.set_ylabel('Extensive Discusssion')

fig.suptitle('Independent vs. Dependent Variable')

# Set background color to white
fig.patch.set_facecolor('white')

# Remove grid lines
ax1.grid(False)
ax2.grid(False)

# Adjust spacing between plots
plt.tight_layout()

# Save plot
plt.savefig(f'plots/Ind_vs_Dep.png', dpi=300)

# Show the plots
plt.show()

# 2. Little or no multi-collinearity
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif_data.to_latex(index=False, float_format="{:.1f}".format))

correlation_matrix = X.corr()
print(correlation_matrix.to_latex())

# 3. Little or no autocorrelation:

# 4. Homoscedasticity
print(X.describe().to_latex())
# Out:
# \begin{tabular}{lr}
# \toprule
# feature & VIF \\
# \midrule
# prob_neg & 1.7 \\
# identity_attack & 1.8 \\
# personal_attack & 1.1 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrr}
# \toprule
#  & prob_neg & identity_attack & personal_attack \\
# \midrule
# prob_neg & 1.000000 & 0.217969 & 0.006826 \\
# identity_attack & 0.217969 & 1.000000 & 0.032564 \\
# personal_attack & 0.006826 & 0.032564 & 1.000000 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrr}
# \toprule
#  & prob_neg & identity_attack & personal_attack \\
# \midrule
# count & 134883.000000 & 134883.000000 & 134883.000000 \\
# mean & 0.418578 & 0.394927 & 0.099471 \\
# std & 0.452481 & 0.271002 & 0.299295 \\
# min & 0.000004 & 0.000000 & 0.000000 \\
# 25% & 0.005772 & 0.158129 & 0.000000 \\
# 50% & 0.074081 & 0.337739 & 0.000000 \\
# 75% & 0.964480 & 0.604080 & 0.000000 \\
# max & 0.999740 & 1.000000 & 1.000000 \\
# \bottomrule
# \end{tabular}
